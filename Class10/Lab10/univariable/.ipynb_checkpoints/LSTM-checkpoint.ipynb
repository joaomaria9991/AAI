# %%
# %pip install keras
# %pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (2.7.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (2.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: absl-py>=0.4.0 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: numpy>=1.14.5 in /Library/Python/3.8/site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (0.23.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (1.41.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (0.33.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: libclang>=9.0.1 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard~=2.6 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (1.13.3)
# Requirement already satisfied: h5py>=2.9.0 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (41.2.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorboard~=2.6->tensorflow) (3.3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorboard~=2.6->tensorflow) (2.25.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorboard~=2.6->tensorflow) (2.0.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from tensorboard~=2.6->tensorflow) (2.3.3)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Python/3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (4.0.0)
# Requirement already satisfied: zipp>=0.5 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/eugenio/Library/Python/3.8/lib/python/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

df = pd.read_csv('data.csv', usecols=[1], engine='python')
print(df.shape)
print(df.info())
print(df.describe())
plt.plot(df)
plt.show()
# Out:
# (144, 1)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Passengers  144 non-null    int64
# dtypes: int64(1)
# memory usage: 1.2 KB
# None
#        Passengers
# count  144.000000
# mean   280.298611
# std    119.966317
# min    104.000000
# 25%    180.000000
# 50%    265.500000
# 75%    360.500000
# max    622.000000

# %%
# fix random seed for reproducibility
np.random.seed(7)

# prepare float values
dataset = df.values
dataset = df.astype('float32')

# QUESTION: why do we need to normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# split into train and test sets
train_size = int(len(dataset) * 0.70)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 100 44

# %%
# Convert an array of values into a dataset matrix
# This default will create a dataset where X is the number of passengers at a given time (t) and Y is the number of passengers at the next time (t + look_back).
def create_dataset(df, look_back=1):
	dataX, dataY = [], []
	for i in range(len(df)-look_back-1):
		a = df[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)


## The LSTM network expects the input data (X) to be provided with a specific array structure in the form of: [samples, time steps, features].
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
trainX.shape,testX.shape
# Out:
# ((98, 1, 1), (42, 1, 1))

# %% [markdown]
# QUESTIONS: Several here....

# %%
## THE NETWORK

# create and fit the LSTM network with 1 hiddhen layer and 4 LSTM blocks
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
model.summary()
# Out:
# Epoch 1/100
# 98/98 - 2s - loss: 0.0507 - 2s/epoch - 24ms/step
# Epoch 2/100
# 98/98 - 0s - loss: 0.0252 - 305ms/epoch - 3ms/step
# Epoch 3/100
# 98/98 - 0s - loss: 0.0181 - 165ms/epoch - 2ms/step
# Epoch 4/100
# 98/98 - 0s - loss: 0.0162 - 236ms/epoch - 2ms/step
# Epoch 5/100
# 98/98 - 0s - loss: 0.0152 - 404ms/epoch - 4ms/step
# Epoch 6/100
# 98/98 - 0s - loss: 0.0141 - 323ms/epoch - 3ms/step
# Epoch 7/100
# 98/98 - 0s - loss: 0.0129 - 211ms/epoch - 2ms/step
# Epoch 8/100
# 98/98 - 0s - loss: 0.0117 - 215ms/epoch - 2ms/step
# Epoch 9/100
# 98/98 - 0s - loss: 0.0106 - 286ms/epoch - 3ms/step
# Epoch 10/100
# 98/98 - 0s - loss: 0.0095 - 322ms/epoch - 3ms/step
# Epoch 11/100
# 98/98 - 0s - loss: 0.0084 - 251ms/epoch - 3ms/step
# Epoch 12/100
# 98/98 - 0s - loss: 0.0074 - 270ms/epoch - 3ms/step
# Epoch 13/100
# 98/98 - 0s - loss: 0.0064 - 267ms/epoch - 3ms/step
# Epoch 14/100
# 98/98 - 0s - loss: 0.0056 - 295ms/epoch - 3ms/step
# Epoch 15/100
# 98/98 - 0s - loss: 0.0047 - 288ms/epoch - 3ms/step
# Epoch 16/100
# 98/98 - 0s - loss: 0.0042 - 296ms/epoch - 3ms/step
# Epoch 17/100
# 98/98 - 0s - loss: 0.0035 - 331ms/epoch - 3ms/step
# Epoch 18/100
# 98/98 - 0s - loss: 0.0031 - 326ms/epoch - 3ms/step
# Epoch 19/100
# 98/98 - 0s - loss: 0.0027 - 284ms/epoch - 3ms/step
# Epoch 20/100
# 98/98 - 0s - loss: 0.0026 - 309ms/epoch - 3ms/step
# Epoch 21/100
# 98/98 - 0s - loss: 0.0024 - 289ms/epoch - 3ms/step
# Epoch 22/100
# 98/98 - 0s - loss: 0.0023 - 283ms/epoch - 3ms/step
# Epoch 23/100
# 98/98 - 0s - loss: 0.0022 - 292ms/epoch - 3ms/step
# Epoch 24/100
# 98/98 - 0s - loss: 0.0022 - 296ms/epoch - 3ms/step
# Epoch 25/100
# 98/98 - 0s - loss: 0.0022 - 227ms/epoch - 2ms/step
# Epoch 26/100
# 98/98 - 0s - loss: 0.0021 - 369ms/epoch - 4ms/step
# Epoch 27/100
# 98/98 - 0s - loss: 0.0022 - 304ms/epoch - 3ms/step
# Epoch 28/100
# 98/98 - 0s - loss: 0.0021 - 237ms/epoch - 2ms/step
# Epoch 29/100
# 98/98 - 0s - loss: 0.0021 - 326ms/epoch - 3ms/step
# Epoch 30/100
# 98/98 - 0s - loss: 0.0022 - 306ms/epoch - 3ms/step
# Epoch 31/100
# 98/98 - 0s - loss: 0.0022 - 199ms/epoch - 2ms/step
# Epoch 32/100
# 98/98 - 0s - loss: 0.0021 - 319ms/epoch - 3ms/step
# Epoch 33/100
# 98/98 - 0s - loss: 0.0021 - 279ms/epoch - 3ms/step
# Epoch 34/100
# 98/98 - 0s - loss: 0.0021 - 224ms/epoch - 2ms/step
# Epoch 35/100
# 98/98 - 0s - loss: 0.0021 - 231ms/epoch - 2ms/step
# Epoch 36/100
# 98/98 - 0s - loss: 0.0021 - 217ms/epoch - 2ms/step
# Epoch 37/100
# 98/98 - 0s - loss: 0.0021 - 217ms/epoch - 2ms/step
# Epoch 38/100
# 98/98 - 0s - loss: 0.0021 - 213ms/epoch - 2ms/step
# Epoch 39/100
# 98/98 - 0s - loss: 0.0021 - 243ms/epoch - 2ms/step
# Epoch 40/100
# 98/98 - 0s - loss: 0.0021 - 258ms/epoch - 3ms/step
# Epoch 41/100
# 98/98 - 0s - loss: 0.0021 - 260ms/epoch - 3ms/step
# Epoch 42/100
# 98/98 - 0s - loss: 0.0021 - 302ms/epoch - 3ms/step
# Epoch 43/100
# 98/98 - 0s - loss: 0.0021 - 258ms/epoch - 3ms/step
# Epoch 44/100
# 98/98 - 0s - loss: 0.0021 - 289ms/epoch - 3ms/step
# Epoch 45/100
# 98/98 - 0s - loss: 0.0022 - 263ms/epoch - 3ms/step
# Epoch 46/100
# 98/98 - 0s - loss: 0.0021 - 287ms/epoch - 3ms/step
# Epoch 47/100
# 98/98 - 0s - loss: 0.0022 - 283ms/epoch - 3ms/step
# Epoch 48/100
# 98/98 - 0s - loss: 0.0022 - 274ms/epoch - 3ms/step
# Epoch 49/100
# 98/98 - 0s - loss: 0.0021 - 301ms/epoch - 3ms/step
# Epoch 50/100
# 98/98 - 0s - loss: 0.0021 - 279ms/epoch - 3ms/step
# Epoch 51/100
# 98/98 - 0s - loss: 0.0022 - 347ms/epoch - 4ms/step
# Epoch 52/100
# 98/98 - 0s - loss: 0.0021 - 309ms/epoch - 3ms/step
# Epoch 53/100
# 98/98 - 0s - loss: 0.0021 - 256ms/epoch - 3ms/step
# Epoch 54/100
# 98/98 - 0s - loss: 0.0021 - 293ms/epoch - 3ms/step
# Epoch 55/100
# 98/98 - 0s - loss: 0.0021 - 273ms/epoch - 3ms/step
# Epoch 56/100
# 98/98 - 0s - loss: 0.0021 - 294ms/epoch - 3ms/step
# Epoch 57/100
# 98/98 - 0s - loss: 0.0021 - 248ms/epoch - 3ms/step
# Epoch 58/100
# 98/98 - 0s - loss: 0.0021 - 207ms/epoch - 2ms/step
# Epoch 59/100
# 98/98 - 0s - loss: 0.0021 - 211ms/epoch - 2ms/step
# Epoch 60/100
# 98/98 - 0s - loss: 0.0021 - 218ms/epoch - 2ms/step
# Epoch 61/100
# 98/98 - 0s - loss: 0.0021 - 316ms/epoch - 3ms/step
# Epoch 62/100
# 98/98 - 0s - loss: 0.0021 - 393ms/epoch - 4ms/step
# Epoch 63/100
# 98/98 - 0s - loss: 0.0021 - 210ms/epoch - 2ms/step
# Epoch 64/100
# 98/98 - 0s - loss: 0.0021 - 182ms/epoch - 2ms/step
# Epoch 65/100
# 98/98 - 0s - loss: 0.0021 - 188ms/epoch - 2ms/step
# Epoch 66/100
# 98/98 - 0s - loss: 0.0021 - 149ms/epoch - 2ms/step
# Epoch 67/100
# 98/98 - 0s - loss: 0.0021 - 135ms/epoch - 1ms/step
# Epoch 68/100
# 98/98 - 0s - loss: 0.0022 - 234ms/epoch - 2ms/step
# Epoch 69/100
# 98/98 - 0s - loss: 0.0021 - 390ms/epoch - 4ms/step
# Epoch 70/100
# 98/98 - 0s - loss: 0.0021 - 357ms/epoch - 4ms/step
# Epoch 71/100
# 98/98 - 0s - loss: 0.0021 - 200ms/epoch - 2ms/step
# Epoch 72/100
# 98/98 - 0s - loss: 0.0021 - 170ms/epoch - 2ms/step
# Epoch 73/100
# 98/98 - 0s - loss: 0.0021 - 157ms/epoch - 2ms/step
# Epoch 74/100
# 98/98 - 0s - loss: 0.0021 - 207ms/epoch - 2ms/step
# Epoch 75/100
# 98/98 - 0s - loss: 0.0022 - 200ms/epoch - 2ms/step
# Epoch 76/100
# 98/98 - 0s - loss: 0.0021 - 169ms/epoch - 2ms/step
# Epoch 77/100
# 98/98 - 0s - loss: 0.0021 - 183ms/epoch - 2ms/step
# Epoch 78/100
# 98/98 - 0s - loss: 0.0021 - 167ms/epoch - 2ms/step
# Epoch 79/100
# 98/98 - 0s - loss: 0.0021 - 180ms/epoch - 2ms/step
# Epoch 80/100
# 98/98 - 0s - loss: 0.0021 - 174ms/epoch - 2ms/step
# Epoch 81/100
# 98/98 - 0s - loss: 0.0021 - 161ms/epoch - 2ms/step
# Epoch 82/100
# 98/98 - 0s - loss: 0.0021 - 168ms/epoch - 2ms/step
# Epoch 83/100
# 98/98 - 0s - loss: 0.0021 - 168ms/epoch - 2ms/step
# Epoch 84/100
# 98/98 - 0s - loss: 0.0021 - 170ms/epoch - 2ms/step
# Epoch 85/100
# 98/98 - 0s - loss: 0.0021 - 313ms/epoch - 3ms/step
# Epoch 86/100
# 98/98 - 0s - loss: 0.0021 - 485ms/epoch - 5ms/step
# Epoch 87/100
# 98/98 - 0s - loss: 0.0021 - 233ms/epoch - 2ms/step
# Epoch 88/100
# 98/98 - 0s - loss: 0.0021 - 302ms/epoch - 3ms/step
# Epoch 89/100
# 98/98 - 0s - loss: 0.0021 - 362ms/epoch - 4ms/step
# Epoch 90/100
# 98/98 - 0s - loss: 0.0021 - 164ms/epoch - 2ms/step
# Epoch 91/100
# 98/98 - 0s - loss: 0.0021 - 265ms/epoch - 3ms/step
# Epoch 92/100
# 98/98 - 0s - loss: 0.0021 - 384ms/epoch - 4ms/step
# Epoch 93/100
# 98/98 - 0s - loss: 0.0021 - 350ms/epoch - 4ms/step
# Epoch 94/100
# 98/98 - 0s - loss: 0.0021 - 233ms/epoch - 2ms/step
# Epoch 95/100
# 98/98 - 0s - loss: 0.0021 - 225ms/epoch - 2ms/step
# Epoch 96/100
# 98/98 - 0s - loss: 0.0021 - 392ms/epoch - 4ms/step
# Epoch 97/100
# 98/98 - 0s - loss: 0.0021 - 383ms/epoch - 4ms/step
# Epoch 98/100
# 98/98 - 0s - loss: 0.0021 - 356ms/epoch - 4ms/step
# Epoch 99/100
# 98/98 - 0s - loss: 0.0021 - 317ms/epoch - 3ms/step
# Epoch 100/100
# 98/98 - 0s - loss: 0.0020 - 198ms/epoch - 2ms/step
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 4)                 96
#
#  dense_6 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 24.45 RMSE
# Test Score: 265.70 RMSE

# %%
## VISUALIZE THE RESULTS
fig=plt.figure(figsize=(8,8), dpi= 100, facecolor='w', edgecolor='k')

# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# QUESTIONS: Several here....
