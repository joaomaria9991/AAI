# %%
pip install -U scikit-fuzzy
# Out:
# Collecting scikit-fuzzy
#   Downloading scikit-fuzzy-0.4.2.tar.gz (993 kB)
# Requirement already satisfied: numpy>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-fuzzy) (1.20.1)
# Requirement already satisfied: scipy>=0.9.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-fuzzy) (1.6.2)
# Requirement already satisfied: networkx>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-fuzzy) (2.5)
# Requirement already satisfied: decorator>=4.3.0 in c:\programdata\anaconda3\lib\site-packages (from networkx>=1.9.0->scikit-fuzzy) (5.0.6)
# Building wheels for collected packages: scikit-fuzzy
#   Building wheel for scikit-fuzzy (setup.py): started
#   Building wheel for scikit-fuzzy (setup.py): finished with status 'done'
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894069 sha256=75380965aefd7e3f0f971a61cae19eb8eb3ebc953a849634462cbaeab1486b04
#   Stored in directory: c:\users\joão maria\appdata\local\pip\cache\wheels\2c\04\80\7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# Installing collected packages: scikit-fuzzy
# Successfully installed scikit-fuzzy-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

MIN = 0
MAX = 75

# Create universe of discourse in Python using linspace ()
X = np.linspace(start=MIN, stop=MAX, num=75, endpoint=True, retstep=False)
X
# Out:
# array([ 0.        ,  1.01351351,  2.02702703,  3.04054054,  4.05405405,
#         5.06756757,  6.08108108,  7.09459459,  8.10810811,  9.12162162,
#        10.13513514, 11.14864865, 12.16216216, 13.17567568, 14.18918919,
#        15.2027027 , 16.21621622, 17.22972973, 18.24324324, 19.25675676,
#        20.27027027, 21.28378378, 22.2972973 , 23.31081081, 24.32432432,
#        25.33783784, 26.35135135, 27.36486486, 28.37837838, 29.39189189,
#        30.40540541, 31.41891892, 32.43243243, 33.44594595, 34.45945946,
#        35.47297297, 36.48648649, 37.5       , 38.51351351, 39.52702703,
#        40.54054054, 41.55405405, 42.56756757, 43.58108108, 44.59459459,
#        45.60810811, 46.62162162, 47.63513514, 48.64864865, 49.66216216,
#        50.67567568, 51.68918919, 52.7027027 , 53.71621622, 54.72972973,
#        55.74324324, 56.75675676, 57.77027027, 58.78378378, 59.7972973 ,
#        60.81081081, 61.82432432, 62.83783784, 63.85135135, 64.86486486,
#        65.87837838, 66.89189189, 67.90540541, 68.91891892, 69.93243243,
#        70.94594595, 71.95945946, 72.97297297, 73.98648649, 75.        ])

# %%
# FUSSIFICATION
MIDDLE = 50
interval1 = [MIN, MIDDLE/2, MIDDLE]
interval2 = [MIDDLE/2, MIDDLE, MAX]
interval3 = [MIDDLE, MAX, MAX]
interval4= [MIN,MIN,MIDDLE/2]
young = fuzz.membership.trimf(X, interval1)
middle_aged = fuzz.membership.trimf(X, interval2)
old = fuzz.membership.trimf(X, interval3)
baby=fuzz.membership.trimf(X,interval4)

# %%
plt.figure()
plt.plot(X, young)
plt.title("Young")
plt.grid(True)

# %%
## Show the membership function for middle_aged
plt.figure()
plt.plot(X, middle_aged)
plt.title("Middle Aged")
plt.grid(True)

# %%
plt.figure()
plt.plot(X, old)
plt.title("Old")
plt.grid(True)

# %%
## Compute and show the COMPLEMENT of young
complement_young = 1 - young
plt.figure()
plt.plot(X, complement_young)
plt.title("Complement Young")
plt.grid(True)

# %%
## Compute and show the UNION between young and middle_aged
young_or_middle = np.maximum(young,middle_aged)
plt.figure()
plt.plot(X, young_or_middle)
plt.title("Young or Middle")
plt.grid(True)

# %%
## Compute and show the INTERSECTION between young and middle_aged
young_and_middle = np.minimum(young,middle_aged)
plt.figure()
plt.plot(X, young_and_middle)
plt.title("Young and Middle")
plt.grid(True)

# %%
plt.figure()
plt.plot(X, baby)
plt.title("DaBaby")
plt.grid(True)

# %%
#Young and Middle à la pate

young_and_middle = np.array([min(a,b) for a,b in zip(young,middle_aged)])

plt.figure()
plt.plot(X, young_and_middle)
plt.title("Young and Middle Aged")
plt.grid(True)
